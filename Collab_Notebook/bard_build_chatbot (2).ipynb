# %% [markdown]
# # Chatbot w/ Bard API

# %% [markdown]
# ## Setup Environment

# %%
# !pip install bardapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 60.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 84.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.8 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=d222d2d9334f80c569246b162fc328f3ad180d55e6a39d9b88228c9d30081080
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# ...

# %%
from bardapi import Bard
import os
import time

# %%
# Replace XXXX with the values you get from __Secure-1PSID
os.environ['_BARD_API_KEY']='cAj6gWlnrYB1CIl2uDiFxVaNaeFDv-YBnXhrFd3lLB_CwXYOXgtHbIZ_bFqD2AUsSvOEwQ.'

# %%
# import requests
# from bardapi.constants import SESSION_HEADERS
# from bardapi import Bard
# import json
# import os

# def load_cookie(element_name):
#     with open(os.getcwd() + "/" + "bard.json", "r", encoding="utf-8") as file:
#         data = json.load(file)
#         if isinstance(data, list):
#             for item in data:
#                 if item.get("name") == element_name:
#                     return item.get("value")
#         return None

# _1PSID = load_cookie("__Secure-1PSID")
# _1PSIDTS = load_cookie("__Secure-1PSIDTS")
# _1PSIDCC = load_cookie("__Secure-1PSIDCC")
# session = requests.Session()
# session.headers = SESSION_HEADERS
# session.cookies.set("__Secure-1PSID", _1PSID)
# session.cookies.set("__Secure-1PSIDTS", _1PSIDTS)
# session.cookies.set("__Secure-1PSIDCC", _1PSIDCC)

# bard = Bard(token=_1PSID, session=session)
# print(bard.get_answer("gnomes")['content'])

# %%
# import requests
# from bardapi.constants import SESSION_HEADERS
# from bardapi import Bard

# token = "xxxxx"

# session = requests.Session()
# session.headers = SESSION_HEADERS
# session.cookies.set("__Secure-1PSID", token)
# session.cookies.set("__Secure-1PSIDTS", "<VALUE>")
# session.cookies.set("__Secure-1PSIDCC", "<VALUE>")

# bard = Bard(token=token, session=session)

# %% [markdown]
# ## Simplest Chatbot

# %%
# Set your input text
# input_text = "Why is the sky blue?"
input_text = "What is the featured smartphones in verizon"
print(Bard().get_answer(input_text)['content'])

# %%
links = [
    "https://www.verizon.com/",
    "https://www.verizon.com/accessibility",
    "https://www.verizon.com/business/",
    "https://www.verizon.com/stores/",
    "https://www.verizon.com/shop/",
    "https://www.verizon.com/deals/",
    "https://www.verizon.com/deals/smartphones/",
    "https://www.verizon.com/home/internet/fios-fastest-internet/bundles/",
    "https://www.verizon.com/bring-your-own-device/",
    "https://www.verizon.com/deals/products/",
    "https://www.verizon.com/referafriend/",
    "https://www.verizon.com/smartphones/",
    "https://www.verizon.com/5g/phones/",
    "https://www.verizon.com/smartphones/apple-iphone-15-pro/",
    "https://www.verizon.com/smartphones/apple-iphone-15/",
    "https://www.verizon.com/smartphones/samsung-galaxy-s23-ultra/",
    "https://www.verizon.com/smartphones/google-pixel-8-pro/",
    "https://www.verizon.com/featured/shop-phones-devices/",
    "https://www.verizon.com/trade-in/",
    "https://www.verizon.com/connected-smartwatches/",
    "https://www.verizon.com/products/",
    "https://www.verizon.com/phone-tablet-accessories/",
    "https://www.verizon.com/batteries-and-chargers/",
    "https://www.verizon.com/audio/",
    "https://www.verizon.com/gaming/gaming-store/",
    "https://www.verizon.com/smart-home/",
    "https://www.verizon.com/plans/",

    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-iot",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-digital-signage",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-law-enforcement",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-revenue",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-consumer-iott",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-automotive",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-vivint",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-ambulance",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-public-safety",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-non-profit",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-public-relations",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-public-information-officer",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-privacy-officer",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-privacy-officer-2",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-privacy-officer-3",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-law-enforcement-data",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-legal-counsel",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-internet",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-internet-device",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-personal",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-california",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-non-u-s",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-general",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-chapter-558",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-esg",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-protective",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca-privacy-notice-drone",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/ca-privacy/ca--notice.pdf",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/information-requests/information-requests-right-know",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/information-requests/information-requests-right-deletion",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/information-requests/information-requests-right-data-portability",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/information-requests/information-requests-right-opt-out",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/information-requests/information-requests-right-verification",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/information-requests/information-requests-right-notice",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/information-requests/information-requests-form",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/information-requests/information-requests-student",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/opt-out-center/opt-out-center-choice",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/opt-out-center/opt-out-center-mobile-device-choices",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/opt-out-center/opt-out-center-preferences",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/opt-out-center/opt-out-center-mobile-apps",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/opt-out-center/opt-out-center-online-advertising",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/opt-out-center/opt-out-center-other-opt-out-choices",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/opt-out-center/opt-out-center-student",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/opt-out-center/opt-out-center-sign-up",
    "https://www.verizon.com/about/our-company/privacy/privacy-policy/opt-out-center/opt-out-center-sign-in"
  ]

# %%
import json

# Define a list of links


# Initialize an empty dictionary to store URL-related words
url_related_words = {}

# Process each link to extract related words
for link in links:
    # Split the URL by '/'
    url_parts = link.split('/')
    # Remove empty parts and common words like 'www'
    related_words = [part for part in url_parts if part and part != 'www' and part != 'https:' and part != 'www.verizon.com']
    for part in related_words:
      split_part = part.split('-')
      if len(split_part) > 1:
        related_words.extend(split_part)
    # Get the last word in the URL as the primary related word
    if related_words:
        # Get the last word in the URL as the primary related word
        primary_related_word = related_words[-1]
    else:
        # If there are no related words, use a placeholder
        primary_related_word = "verizon"
    # Add the related words to the dictionary
    url_related_words[link] = related_words

# Save the data to a JSON file
with open('url_related_words.json', 'w') as json_file:
    json.dump(url_related_words, json_file, indent=4)

print("JSON file created successfully.")
# Out:
# JSON file created successfully.

# %%
# import json

# # Define a list of links


# # Initialize an empty dictionary to store URL-related words
# url_related_words = {}

# # Process each link to extract related words
# for link in links1:
#     # Split the URL by '/'
#     url_parts = link.split('/')
#     # Remove empty parts and common words like 'www'
#     related_words = [part for part in url_parts if part and part != 'www' and part != 'https:' and part != 'www.verizon.com']
#     # Get the last word in the URL as the primary related word
#     if related_words:
#         # Get the last word in the URL as the primary related word
#         primary_related_word = related_words[-1]
#     else:
#         # If there are no related words, use a placeholder
#         primary_related_word = "verizon"
#     # Add the related words to the dictionary
#     url_related_words[link] = related_words

# # Save the data to a JSON file
# with open('url_related_words2.json', 'w') as json_file:
#     json.dump(url_related_words, json_file, indent=4)

# print("JSON file created successfully.")
# Out:
# JSON file created successfully.

# %%
import json

# Define a list of links


# Initialize an empty dictionary to store URL-related words
url_related_words = {}

# Process each link to extract related words
for link in links1:
    # Split the URL by '/'
    url_parts = link.split('/')
    # Remove empty parts and common words like 'www'
    related_words = [part for part in url_parts if part and part != 'www' and part != 'https:' and part != 'www.verizon.com']
    for part in related_words:
      split_part = part.split('-')
      if len(split_part) > 1:
        related_words.extend(split_part)
    # Get the last word in the URL as the primary related word
    if related_words:
        # Get the last word in the URL as the primary related word
        primary_related_word = related_words[-1]
    else:
        # If there are no related words, use a placeholder
        primary_related_word = "verizon"
    # Add the related words to the dictionary
    url_related_words[link] = related_words

# Save the data to a JSON file
with open('url_related_words2.json', 'w') as json_file:
    json.dump(url_related_words, json_file, indent=4)

print("JSON file created successfully.")
# Out:
# JSON file created successfully.

# %%
import requests
import re
import urllib.request
from bs4 import BeautifulSoup
from collections import deque
from html.parser import HTMLParser
from urllib.parse import urlparse
import os
import time

# Regex pattern to match a URL
HTTP_URL_PATTERN = r'^http[s]*://.+'

# Define root domain to crawl
domain = "verizon.com"
full_url = "https://verizon.com/"







def sanitize_url(url):
    return url[8:].replace("/", "_").replace(".", "_")


def crawl(url):
    # Parse the URL and get the domain
    local_domain = "verizon.com"

    # Create a queue to store the URLs to crawl

    # Create a set to store the URLs that have already been seen (no duplicates)


    # Create a directory to store the text files
    if not os.path.exists("text/"):
            os.mkdir("text/")

    if not os.path.exists("text/"+local_domain+"/"):
            os.mkdir("text/" + local_domain + "/")

    # Create a directory to store the csv files
    if not os.path.exists("processed"):
            os.mkdir("processed")

    # While the queue is not empty, continue crawling

    print(url) # for debugging and to see the progress

    sanitized_url = sanitize_url(url)

    file_path = os.path.join("text", local_domain, sanitized_url + ".txt")

        # Ensure the directory structure exists
    os.makedirs(os.path.dirname(file_path), exist_ok=True)

        # Save text from the URL to a .txt file
    with open(file_path, "w") as f:

            text = Bard().get_answer(link+"get information from this link")['content']

            # If the crawler gets to a page that requires JavaScript, it will stop the crawl
            if ("You need to enable JavaScript to run this app." in text):
                print("Unable to parse page " + url + " due to JavaScript being required")

            # Otherwise, write the text to the file in the text directory
            f.write(text)

# %%
# for link in links:
#     crawl(link)

# %%
new_list = []
for link in links:
    new_list.append(Bard().get_answer(link+"get information from this link")['content'])

# %%
for i in range(0,len(new_list)):
  print(links[i]+"\n");
  print(new_list[i]);
# Out:
# https://www.verizon.com/
#
# I'm sorry. I'm not able to access the website(s) you've provided. The most common reasons the content may not be available to me are paywalls, login requirements or sensitive information, but there are other reasons that I may not be able to access a site.
#
# https://www.verizon.com/accessibility
#
# This is an article about Verizon’s Accessibility Resource Center. It discusses what the center is and what it offers. The center offers a variety of resources to help customers with disabilities, including information on products and services, tips for using Verizon products and services, and contact information for customer support. Verizon is committed to making its digital content accessible to all customers.
#
# https://www.verizon.com/business/
#
# Here is a summary of the page:
# ...

# %%
# with open(details_list, "w") as file:
#     for link in new_list:
#         file.write(link + "\n")

# %%
with open(links_list, "w") as file:
    for link in links:
        file.write(link + "\n")

# %%
link_mapping = {original_link: new_link for original_link, new_link in zip(links, new_list)}

# Define the output JSON file name
output_file = "link_mapping.json"

# Save the link mapping dictionary to a JSON file
with open(output_file, "w") as json_file:
    json.dump(link_mapping, json_file, indent=4)

print("Link mapping saved to", output_file)

# %%
input_text = "What is the featured smartphones in verizon? in which link can i find them?"
print(Bard().get_answer(input_text)['content'])
# Out:
# The featured smartphones on Verizon as of October 14, 2023 are:
#
# * Google Pixel 8 Pro
# * Samsung Galaxy S23 Ultra
# * Apple iPhone 14 Pro Max
# * Motorola Edge+
# * OnePlus 11 Pro
#
# You can find these featured smartphones on the Verizon website at the following link: https://www.verizon.com/smartphones/
#
# **Note:** This link may change in the future, so it is always best to check the Verizon website for the most up-to-date information on featured smartphones.
#
# In addition to the featured smartphones, Verizon also offers a wide variety of other smartphones to choose from, including budget-friendly options and smartphones with specific features, such as long battery life or a great camera. You can browse all of the smartphones that Verizon offers on the Verizon website at the following link: https://www.verizon.com/smartphones/

# %%
example1 = "all links.txt"
file1 = open(example1, "r")

FileContent = file1.read()
print(FileContent)
# Out:
# links:
# link: https://www.verizon.com/
# 	link: https://www.verizon.com/accessibility
# 	link: https://www.verizon.com/business/
# 	link: https://www.verizon.com/stores/
# 	link: https://www.verizon.com/shop/
# 	link: https://www.verizon.com/deals/
# 	link: https://www.verizon.com/deals/smartphones/
# 	link: https://www.verizon.com/home/internet/fios-fastest-internet/bundles/
# 	link: https://www.verizon.com/bring-your-own-device/
# 	link: https://www.verizon.com/deals/products/
# 	link: https://www.verizon.com/referafriend/
# 	link: https://www.verizon.com/smartphones/
# 	link: https://www.verizon.com/5g/phones/
# 	link: https://www.verizon.com/smartphones/apple-iphone-15-pro/
# 	link: https://www.verizon.com/smartphones/apple-iphone-15/
# 	link: https://www.verizon.com/smartphones/samsung-galaxy-s23-ultra/
# 	link: https://www.verizon.com/smartphones/google-pixel-8-pro/
# 	link: https://www.verizon.com/featured/shop-phones-devices/
# 	link: https://www.verizon.com/trade-in/
# ...

# %%
prompt =f"""
  Your task is to act as a chatbot and a relevant web page provider.
  I'll give you text of all available routes in verizon website.
  And your job is to give the user the correct route along with the info you have for their query.
  Don't be too much conversational. explain the answer and give them the link.
  route the user based on studying the route and matching the words and sort all the routes with same word in together and prsent them with the speciofic route if asked otherwise most matched general route.
  Text is shared below, delimited with triple backticks:
  ```{FileContent}```
  """

# %%
def get_completion(prompt):
  while True:
     query = input("What do you want to ask? ")
     response = Bard().get_answer(prompt+query)['content']
     print(response)

# %%
get_completion(prompt)
# Out:
# What do you want to ask? featured phones in verizon
# Response Error: b')]}\'\n\n38\n[["wrb.fr",null,null,null,null,[3]]]\n56\n[["di",163],["af.httprm",162,"7599593932973630075",0]]\n25\n[["e",4,null,null,131]]\n'.
# Unable to get response.
# Please double-check the cookie values and verify your network environment or google account.
# What do you want to ask? featured phones
# Response Error: b')]}\'\n\n38\n[["wrb.fr",null,null,null,null,[3]]]\n57\n[["di",178],["af.httprm",178,"-1037920647054871102",0]]\n25\n[["e",4,null,null,132]]\n'.
# Unable to get response.
# Please double-check the cookie values and verify your network environment or google account.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-e125e59998f2> in <cell line: 1>()
# ----> 1 get_completion(prompt)
#
# <ipython-input-30-778a3e325b8d> in get_completion(prompt)
# ...

# %%
for i in range(len(new_text)):
  prompt =f"""
  Your task is to act as a chatbot and a relevant web page provider.
  I'll give you text of all available routes in verizon website.
  And your job is to give the user the correct route along with the info you have for their query.
  Don't be too much conversational. explain the answer and give them the link.
  route the user based on studying the route and matching the words and sort all the routes with same word in together and prsent them with the speciofic route if asked otherwise most matched general route.
  Text is shared below, delimited with triple backticks:
  ```{text[i]}```
  """
  try:
    response = get_completion(prompt)
  except:
    response = get_completion(prompt)
  print(response)
  summary= summary+' ' +response +'\n\n'
  # result.append(response)
  time.sleep(19)  #You can query the model only 3 times in a minute for free, so we need to put some delay

# %% [markdown]
# ## Custom Chatbot
